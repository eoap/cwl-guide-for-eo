# %% [markdown]
# ## Build the container supporting the How-to's

# %% [markdown]
# The `Dockerfile` adds `rasterio` to a GDAL base container image:

# %%
cat ../Dockerfile
# Out:
# ARG GDAL=ubuntu-small-3.6.4
#
# FROM ghcr.io/osgeo/gdal:${GDAL} AS gdal
#
# ARG PYTHON_VERSION=3.11
#
# ENV LANG="C.UTF-8" LC_ALL="C.UTF-8"
#
# RUN apt-get update -qq && \
#     apt-get install -y software-properties-common && \
#     add-apt-repository -y ppa:deadsnakes/ppa && \
#     apt-get update -qq && \
#     DEBIAN_FRONTEND=noninteractive apt-get install -y --no-install-recommends \
#     g++ \
#     gdb \
#     make \
#     python3-pip \
#     python${PYTHON_VERSION} && \
#     rm -rf /var/lib/apt/lists/* && \
#     pip install --no-cache-dir rasterio

# %% [markdown]
# Build the image with `podman` container engine:

# %%
podman build -t rio:latest ..
# Out:
# STEP 1/4: FROM ghcr.io/osgeo/gdal:ubuntu-small-3.6.4 AS gdal
# Trying to pull ghcr.io/osgeo/gdal:ubuntu-small-3.6.4...
# Getting image source signatures
# Copying blob 4f4fb700ef54 [======================================] 32.0b / 32.0b
# Copying blob 4f4fb700ef54 done
# Copying blob 4f4fb700ef54 done
# Copying blob d299e661dc52 [================================] 102.1KiB / 102.1KiB
# Copying blob 4f4fb700ef54 done
# Copying blob d299e661dc52 done
# Copying blob 4f4fb700ef54 done
# Copying blob d299e661dc52 done
# Copying blob 4f4fb700ef54 done
# Copying blob d299e661dc52 done
# Copying blob 2ab09b027e7f [>----------------------------------] 1.1MiB / 28.2MiB
# Copying blob 7bd02f0fc242 [===================>----------------] 2.2MiB / 3.9MiB
# Copying blob d67242ccbe8c [=>---------------------------------] 1.7MiB / 31.0MiB
# Copying blob c16fb3d4a246 [>--------------------------------] 927.1KiB / 57.5MiB
# Copying blob 4f4fb700ef54 done
# Copying blob d299e661dc52 done
# Copying blob 2ab09b027e7f [==>--------------------------------] 2.1MiB / 28.2MiB
# Copying blob 7bd02f0fc242 [==============================>-----] 3.4MiB / 3.9MiB
# Copying blob d67242ccbe8c [===>-------------------------------] 3.1MiB / 31.0MiB
# Copying blob c16fb3d4a246 [>----------------------------------] 1.9MiB / 57.5MiB
# Copying blob 4f4fb700ef54 done
# Copying blob d299e661dc52 done
# Copying blob 2ab09b027e7f [===>-------------------------------] 3.1MiB / 28.2MiB
# Copying blob 7bd02f0fc242 [====================================] 3.9MiB / 3.9MiB
# Copying blob d67242ccbe8c [====>------------------------------] 4.2MiB / 31.0MiB
# Copying blob c16fb3d4a246 [=>---------------------------------] 2.7MiB / 57.5MiB
# Copying blob b3e23ec15d09 [==>-------------------------------] 559.1KiB / 6.3MiB
# Copying blob 4f4fb700ef54 done
# Copying blob d299e661dc52 done
# Copying blob 2ab09b027e7f [====>------------------------------] 3.8MiB / 28.2MiB
# Copying blob 7bd02f0fc242 done
# Copying blob d67242ccbe8c [=====>-----------------------------] 5.0MiB / 31.0MiB
# Copying blob c16fb3d4a246 [=>---------------------------------] 3.2MiB / 57.5MiB
# Copying blob b3e23ec15d09 [=========>--------------------------] 1.7MiB / 6.3MiB
# Copying blob 85740f1073e7 [=====>----------------------------] 319.1KiB / 1.6MiB
# Copying blob 4f4fb700ef54 done
# Copying blob d299e661dc52 done
# Copying blob 2ab09b027e7f [====>------------------------------] 4.3MiB / 28.2MiB
# Copying blob 7bd02f0fc242 done
# Copying blob d67242ccbe8c [=====>-----------------------------] 5.4MiB / 31.0MiB
# Copying blob c16fb3d4a246 [=>---------------------------------] 3.9MiB / 57.5MiB
# Copying blob b3e23ec15d09 [==========>-------------------------] 1.9MiB / 6.3MiB
# Copying blob 85740f1073e7 [=============>--------------------] 693.2KiB / 1.6MiB
# Copying blob 4f4fb700ef54 done
# Copying blob d299e661dc52 done
# Copying blob 2ab09b027e7f [=====>-----------------------------] 4.8MiB / 28.2MiB
# Copying blob 7bd02f0fc242 done
# Copying blob d67242ccbe8c [======>----------------------------] 6.0MiB / 31.0MiB
# Copying blob c16fb3d4a246 [==>--------------------------------] 4.5MiB / 57.5MiB
# Copying blob b3e23ec15d09 [===============>--------------------] 2.8MiB / 6.3MiB
# Copying blob 85740f1073e7 [=================================>--] 1.6MiB / 1.6MiB
# Copying blob 4f4fb700ef54 done
# Copying blob d299e661dc52 done
# Copying blob 2ab09b027e7f [======>----------------------------] 5.6MiB / 28.2MiB
# Copying blob 7bd02f0fc242 done
# Copying blob d67242ccbe8c [=======>---------------------------] 6.8MiB / 31.0MiB
# Copying blob c16fb3d4a246 [==>--------------------------------] 5.0MiB / 57.5MiB
# Copying blob b3e23ec15d09 [======================>-------------] 4.0MiB / 6.3MiB
# Copying blob 85740f1073e7 [====================================] 1.6MiB / 1.6MiB
# Copying blob 4f4fb700ef54 done
# Copying blob d299e661dc52 done
# Copying blob 2ab09b027e7f [=======>---------------------------] 6.3MiB / 28.2MiB
# Copying blob 7bd02f0fc242 done
# Copying blob d67242ccbe8c [=======>---------------------------] 7.5MiB / 31.0MiB
# Copying blob c16fb3d4a246 [==>--------------------------------] 5.5MiB / 57.5MiB
# Copying blob b3e23ec15d09 [=============================>------] 5.3MiB / 6.3MiB
# Copying blob 85740f1073e7 done
# Copying blob dc76c4afb72d [>----------------------------------] 1.3KiB / 82.1KiB
# Copying blob 4f4fb700ef54 done
# Copying blob d299e661dc52 done
# Copying blob 2ab09b027e7f [========>--------------------------] 6.9MiB / 28.2MiB
# Copying blob 7bd02f0fc242 done
# Copying blob d67242ccbe8c [========>--------------------------] 8.3MiB / 31.0MiB
# Copying blob c16fb3d4a246 [==>--------------------------------] 5.6MiB / 57.5MiB
# Copying blob b3e23ec15d09 [=================================>--] 5.9MiB / 6.3MiB
# Copying blob 85740f1073e7 done
# Copying blob dc76c4afb72d [==================================] 82.1KiB / 82.1KiB
# Copying blob 4f4fb700ef54 done
# Copying blob d299e661dc52 done
# Copying blob 2ab09b027e7f [=========>-------------------------] 8.0MiB / 28.2MiB
# Copying blob 7bd02f0fc242 done
# Copying blob d67242ccbe8c [=========>-------------------------] 9.2MiB / 31.0MiB
# Copying blob c16fb3d4a246 [===>-------------------------------] 6.4MiB / 57.5MiB
# Copying blob b3e23ec15d09 [====================================] 6.3MiB / 6.3MiB
# Copying blob 85740f1073e7 done
# Copying blob dc76c4afb72d done
# Copying blob 4f4fb700ef54 done
# Copying blob d299e661dc52 done
# Copying blob 2ab09b027e7f [==========>------------------------] 8.6MiB / 28.2MiB
# Copying blob 7bd02f0fc242 done
# Copying blob d67242ccbe8c [==========>------------------------] 9.6MiB / 31.0MiB
# Copying blob c16fb3d4a246 [===>-------------------------------] 7.0MiB / 57.5MiB
# Copying blob b3e23ec15d09 done
# Copying blob 85740f1073e7 done
# Copying blob dc76c4afb72d done
# Copying blob a33263ea7965 [=========================>------] 127.1KiB / 155.3KiB
# Copying blob 4f4fb700ef54 done
# Copying blob d299e661dc52 done
# Copying blob 2ab09b027e7f [===========>-----------------------] 9.5MiB / 28.2MiB
# Copying blob 7bd02f0fc242 done
# Copying blob d67242ccbe8c [===========>----------------------] 10.6MiB / 31.0MiB
# Copying blob c16fb3d4a246 [====>------------------------------] 7.5MiB / 57.5MiB
# Copying blob b3e23ec15d09 done
# Copying blob 85740f1073e7 done
# Copying blob dc76c4afb72d done
# Copying blob a33263ea7965 [================================] 155.3KiB / 155.3KiB
# Copying blob 4f4fb700ef54 done
# Copying blob d299e661dc52 done
# Copying blob 2ab09b027e7f [===========>----------------------] 10.3MiB / 28.2MiB
# Copying blob 7bd02f0fc242 done
# Copying blob d67242ccbe8c [============>---------------------] 11.6MiB / 31.0MiB
# Copying blob c16fb3d4a246 [====>------------------------------] 8.1MiB / 57.5MiB
# Copying blob b3e23ec15d09 done
# Copying blob 85740f1073e7 done
# Copying blob dc76c4afb72d done
# Copying blob a33263ea7965 done
# Copying blob 4f4fb700ef54 done
# Copying blob d299e661dc52 done
# Copying blob 2ab09b027e7f [=============>--------------------] 11.2MiB / 28.2MiB
# Copying blob 7bd02f0fc242 done
# Copying blob d67242ccbe8c [=============>--------------------] 12.5MiB / 31.0MiB
# Copying blob c16fb3d4a246 [=====>-----------------------------] 9.1MiB / 57.5MiB
# Copying blob b3e23ec15d09 done
# Copying blob 85740f1073e7 done
# Copying blob dc76c4afb72d done
# Copying blob a33263ea7965 done
# Copying blob ac81378f5172 [===============>------------------] 773.2KiB / 1.6MiB
# Copying blob 8691ca415fb0 [===========================>----] 287.1KiB / 333.8KiB
# Copying blob 4f4fb700ef54 done
# Copying blob d299e661dc52 done
# Copying blob 2ab09b027e7f [=============>--------------------] 11.8MiB / 28.2MiB
# Copying blob 7bd02f0fc242 done
# Copying blob d67242ccbe8c [=============>--------------------] 13.0MiB / 31.0MiB
# Copying blob c16fb3d4a246 [=====>-----------------------------] 9.6MiB / 57.5MiB
# Copying blob b3e23ec15d09 done
# Copying blob 85740f1073e7 done
# Copying blob dc76c4afb72d done
# Copying blob a33263ea7965 done
# Copying blob ac81378f5172 [==============================>-----] 1.4MiB / 1.6MiB
# Copying blob 8691ca415fb0 [================================] 333.8KiB / 333.8KiB
# Copying blob 4f4fb700ef54 done
# Copying blob d299e661dc52 done
# Copying blob 2ab09b027e7f [==============>-------------------] 12.6MiB / 28.2MiB
# Copying blob 7bd02f0fc242 done
# Copying blob d67242ccbe8c [===============>------------------] 14.4MiB / 31.0MiB
# Copying blob c16fb3d4a246 [=====>----------------------------] 10.5MiB / 57.5MiB
# Copying blob b3e23ec15d09 done
# Copying blob 85740f1073e7 done
# Copying blob dc76c4afb72d done
# Copying blob a33263ea7965 done
# Copying blob ac81378f5172 [====================================] 1.6MiB / 1.6MiB
# Copying blob 8691ca415fb0 done
# Copying blob 92d593a7c63e [===============================>] 223.1KiB / 224.2KiB
# Copying blob 4f4fb700ef54 done
# Copying blob d299e661dc52 done
# Copying blob 2ab09b027e7f [===============>------------------] 13.2MiB / 28.2MiB
# Copying blob 7bd02f0fc242 done
# Copying blob d67242ccbe8c [================>-----------------] 15.2MiB / 31.0MiB
# Copying blob c16fb3d4a246 [======>---------------------------] 11.1MiB / 57.5MiB
# Copying blob b3e23ec15d09 done
# Copying blob 85740f1073e7 done
# Copying blob dc76c4afb72d done
# Copying blob a33263ea7965 done
# Copying blob ac81378f5172 done
# Copying blob 8691ca415fb0 done
# Copying blob 92d593a7c63e [================================] 224.2KiB / 224.2KiB
# Copying blob 4f4fb700ef54 done
# Copying blob d299e661dc52 done
# Copying blob 2ab09b027e7f [=================>----------------] 14.6MiB / 28.2MiB
# Copying blob 7bd02f0fc242 done
# Copying blob d67242ccbe8c [=================>----------------] 16.5MiB / 31.0MiB
# Copying blob c16fb3d4a246 [======>---------------------------] 12.3MiB / 57.5MiB
# Copying blob b3e23ec15d09 done
# Copying blob 85740f1073e7 done
# Copying blob dc76c4afb72d done
# Copying blob a33263ea7965 done
# Copying blob ac81378f5172 done
# Copying blob 8691ca415fb0 done
# Copying blob 92d593a7c63e done
# Copying blob 4f4fb700ef54 done
# Copying blob d299e661dc52 done
# Copying blob 2ab09b027e7f [=================>----------------] 15.0MiB / 28.2MiB
# Copying blob 7bd02f0fc242 done
# Copying blob d67242ccbe8c [=================>----------------] 16.9MiB / 31.0MiB
# Copying blob c16fb3d4a246 [=======>--------------------------] 12.8MiB / 57.5MiB
# Copying blob b3e23ec15d09 done
# Copying blob 85740f1073e7 done
# Copying blob dc76c4afb72d done
# Copying blob a33263ea7965 done
# Copying blob ac81378f5172 done
# Copying blob 8691ca415fb0 done
# Copying blob 92d593a7c63e done
# Copying blob cb883a52b0ac [>---------------------------------] 415.1KiB / 9.3MiB
# Copying blob 61efb1f3f8fd [===>------------------------------] 153.4KiB / 1.3MiB
# Copying blob 4f4fb700ef54 done
# Copying blob d299e661dc52 done
# Copying blob 2ab09b027e7f [==================>---------------] 15.6MiB / 28.2MiB
# Copying blob 7bd02f0fc242 done
# Copying blob d67242ccbe8c [==================>---------------] 17.6MiB / 31.0MiB
# Copying blob c16fb3d4a246 [=======>--------------------------] 13.7MiB / 57.5MiB
# Copying blob b3e23ec15d09 done
# Copying blob 85740f1073e7 done
# Copying blob dc76c4afb72d done
# Copying blob a33263ea7965 done
# Copying blob ac81378f5172 done
# Copying blob 8691ca415fb0 done
# Copying blob 92d593a7c63e done
# Copying blob cb883a52b0ac [==>-------------------------------] 959.1KiB / 9.3MiB
# Copying blob 61efb1f3f8fd [============================>-------] 1.0MiB / 1.3MiB
# Copying blob 4f4fb700ef54 done
# Copying blob d299e661dc52 done
# Copying blob 2ab09b027e7f [===================>--------------] 16.4MiB / 28.2MiB
# Copying blob 7bd02f0fc242 done
# Copying blob d67242ccbe8c [===================>--------------] 18.5MiB / 31.0MiB
# Copying blob c16fb3d4a246 [=======>--------------------------] 14.0MiB / 57.5MiB
# Copying blob b3e23ec15d09 done
# Copying blob 85740f1073e7 done
# Copying blob dc76c4afb72d done
# Copying blob a33263ea7965 done
# Copying blob ac81378f5172 done
# Copying blob 8691ca415fb0 done
# Copying blob 92d593a7c63e done
# Copying blob cb883a52b0ac [=====>------------------------------] 1.6MiB / 9.3MiB
# Copying blob 61efb1f3f8fd [====================================] 1.3MiB / 1.3MiB
# Copying blob 6aeea3b7fc68 [====================================] 4.0KiB / 4.0KiB
# Copying blob 4f4fb700ef54 done
# Copying blob d299e661dc52 done
# Copying blob 2ab09b027e7f [====================>-------------] 17.4MiB / 28.2MiB
# Copying blob 7bd02f0fc242 done
# Copying blob d67242ccbe8c [=====================>------------] 20.4MiB / 31.0MiB
# Copying blob c16fb3d4a246 [========>-------------------------] 14.9MiB / 57.5MiB
# Copying blob b3e23ec15d09 done
# Copying blob 85740f1073e7 done
# Copying blob dc76c4afb72d done
# Copying blob a33263ea7965 done
# Copying blob ac81378f5172 done
# Copying blob 8691ca415fb0 done
# Copying blob 92d593a7c63e done
# Copying blob cb883a52b0ac [=========>--------------------------] 2.6MiB / 9.3MiB
# Copying blob 61efb1f3f8fd done
# Copying blob 6aeea3b7fc68 done
# Copying blob 4f4fb700ef54 done
# Copying blob d299e661dc52 done
# Copying blob 2ab09b027e7f [=====================>------------] 17.9MiB / 28.2MiB
# Copying blob 7bd02f0fc242 done
# Copying blob d67242ccbe8c [=======================>----------] 21.5MiB / 31.0MiB
# Copying blob c16fb3d4a246 [========>-------------------------] 15.4MiB / 57.5MiB
# Copying blob b3e23ec15d09 done
# Copying blob 85740f1073e7 done
# Copying blob dc76c4afb72d done
# Copying blob a33263ea7965 done
# Copying blob ac81378f5172 done
# Copying blob 8691ca415fb0 done
# Copying blob 92d593a7c63e done
# Copying blob cb883a52b0ac [==========>-------------------------] 2.9MiB / 9.3MiB
# Copying blob 61efb1f3f8fd done
# Copying blob 6aeea3b7fc68 done
# Copying blob 4f4fb700ef54 done
# Copying blob d299e661dc52 done
# Copying blob 2ab09b027e7f [======================>-----------] 19.4MiB / 28.2MiB
# Copying blob 7bd02f0fc242 done
# Copying blob d67242ccbe8c [========================>---------] 22.9MiB / 31.0MiB
# Copying blob c16fb3d4a246 [=========>------------------------] 16.5MiB / 57.5MiB
# Copying blob b3e23ec15d09 done
# Copying blob 85740f1073e7 done
# Copying blob dc76c4afb72d done
# Copying blob a33263ea7965 done
# Copying blob ac81378f5172 done
# Copying blob 8691ca415fb0 done
# Copying blob 92d593a7c63e done
# Copying blob cb883a52b0ac [===============>--------------------] 4.1MiB / 9.3MiB
# Copying blob 61efb1f3f8fd done
# Copying blob 6aeea3b7fc68 done
# Copying blob 4f4fb700ef54 done
# Copying blob d299e661dc52 done
# Copying blob 2ab09b027e7f [=======================>----------] 19.7MiB / 28.2MiB
# Copying blob 7bd02f0fc242 done
# Copying blob d67242ccbe8c [========================>---------] 23.2MiB / 31.0MiB
# Copying blob c16fb3d4a246 [=========>------------------------] 17.0MiB / 57.5MiB
# Copying blob b3e23ec15d09 done
# Copying blob 85740f1073e7 done
# Copying blob dc76c4afb72d done
# Copying blob a33263ea7965 done
# Copying blob ac81378f5172 done
# Copying blob 8691ca415fb0 done
# Copying blob 92d593a7c63e done
# Copying blob cb883a52b0ac [================>-------------------] 4.5MiB / 9.3MiB
# Copying blob 61efb1f3f8fd done
# Copying blob 6aeea3b7fc68 done
# Copying blob 4f4fb700ef54 done
# Copying blob d299e661dc52 done
# Copying blob 2ab09b027e7f [========================>---------] 20.8MiB / 28.2MiB
# Copying blob 7bd02f0fc242 done
# Copying blob d67242ccbe8c [=========================>--------] 24.0MiB / 31.0MiB
# Copying blob c16fb3d4a246 [==========>-----------------------] 18.2MiB / 57.5MiB
# Copying blob b3e23ec15d09 done
# Copying blob 85740f1073e7 done
# Copying blob dc76c4afb72d done
# Copying blob a33263ea7965 done
# Copying blob ac81378f5172 done
# Copying blob 8691ca415fb0 done
# Copying blob 92d593a7c63e done
# Copying blob cb883a52b0ac [====================>---------------] 5.4MiB / 9.3MiB
# Copying blob 61efb1f3f8fd done
# Copying blob 6aeea3b7fc68 done
# Copying blob 4f4fb700ef54 done
# Copying blob d299e661dc52 done
# Copying blob 2ab09b027e7f [=========================>--------] 21.7MiB / 28.2MiB
# Copying blob 7bd02f0fc242 done
# Copying blob d67242ccbe8c [==========================>-------] 24.9MiB / 31.0MiB
# Copying blob c16fb3d4a246 [==========>-----------------------] 18.7MiB / 57.5MiB
# Copying blob b3e23ec15d09 done
# Copying blob 85740f1073e7 done
# Copying blob dc76c4afb72d done
# Copying blob a33263ea7965 done
# Copying blob ac81378f5172 done
# Copying blob 8691ca415fb0 done
# Copying blob 92d593a7c63e done
# Copying blob cb883a52b0ac [======================>-------------] 5.9MiB / 9.3MiB
# Copying blob 61efb1f3f8fd done
# Copying blob 6aeea3b7fc68 done
# Copying blob 4f4fb700ef54 done
# Copying blob d299e661dc52 done
# Copying blob 2ab09b027e7f [==========================>-------] 22.3MiB / 28.2MiB
# Copying blob 7bd02f0fc242 done
# Copying blob d67242ccbe8c [===========================>------] 25.6MiB / 31.0MiB
# Copying blob c16fb3d4a246 [==========>-----------------------] 19.0MiB / 57.5MiB
# Copying blob b3e23ec15d09 done
# Copying blob 85740f1073e7 done
# Copying blob dc76c4afb72d done
# Copying blob a33263ea7965 done
# Copying blob ac81378f5172 done
# Copying blob 8691ca415fb0 done
# Copying blob 92d593a7c63e done
# Copying blob cb883a52b0ac [=========================>----------] 6.7MiB / 9.3MiB
# Copying blob 61efb1f3f8fd done
# Copying blob 6aeea3b7fc68 done
# Copying blob 4f4fb700ef54 done
# Copying blob d299e661dc52 done
# Copying blob 2ab09b027e7f [==========================>-------] 22.8MiB / 28.2MiB
# Copying blob 7bd02f0fc242 done
# Copying blob d67242ccbe8c [============================>-----] 26.2MiB / 31.0MiB
# Copying blob c16fb3d4a246 [==========>-----------------------] 19.4MiB / 57.5MiB
# Copying blob b3e23ec15d09 done
# Copying blob 85740f1073e7 done
# Copying blob dc76c4afb72d done
# Copying blob a33263ea7965 done
# Copying blob ac81378f5172 done
# Copying blob 8691ca415fb0 done
# Copying blob 92d593a7c63e done
# Copying blob cb883a52b0ac [============================>-------] 7.5MiB / 9.3MiB
# Copying blob 61efb1f3f8fd done
# Copying blob 6aeea3b7fc68 done
# Copying blob 4f4fb700ef54 done
# Copying blob d299e661dc52 done
# Copying blob 2ab09b027e7f [============================>-----] 23.8MiB / 28.2MiB
# Copying blob 7bd02f0fc242 done
# Copying blob d67242ccbe8c [=============================>----] 27.2MiB / 31.0MiB
# Copying blob c16fb3d4a246 [===========>----------------------] 20.0MiB / 57.5MiB
# Copying blob b3e23ec15d09 done
# Copying blob 85740f1073e7 done
# Copying blob dc76c4afb72d done
# Copying blob a33263ea7965 done
# Copying blob ac81378f5172 done
# Copying blob 8691ca415fb0 done
# Copying blob 92d593a7c63e done
# Copying blob cb883a52b0ac [===============================>----] 8.2MiB / 9.3MiB
# Copying blob 61efb1f3f8fd done
# Copying blob 6aeea3b7fc68 done
# Copying blob 4f4fb700ef54 done
# Copying blob d299e661dc52 done
# Copying blob 2ab09b027e7f [=============================>----] 24.6MiB / 28.2MiB
# Copying blob 7bd02f0fc242 done
# Copying blob d67242ccbe8c [==============================>---] 28.1MiB / 31.0MiB
# Copying blob c16fb3d4a246 [===========>----------------------] 20.9MiB / 57.5MiB
# Copying blob b3e23ec15d09 done
# Copying blob 85740f1073e7 done
# Copying blob dc76c4afb72d done
# Copying blob a33263ea7965 done
# Copying blob ac81378f5172 done
# Copying blob 8691ca415fb0 done
# Copying blob 92d593a7c63e done
# Copying blob cb883a52b0ac [==================================>-] 9.0MiB / 9.3MiB
# Copying blob 61efb1f3f8fd done
# Copying blob 6aeea3b7fc68 done
# Copying blob 4f4fb700ef54 done
# Copying blob d299e661dc52 done
# Copying blob 2ab09b027e7f [=============================>----] 25.3MiB / 28.2MiB
# Copying blob 7bd02f0fc242 done
# Copying blob d67242ccbe8c [==============================>---] 28.7MiB / 31.0MiB
# Copying blob c16fb3d4a246 [============>---------------------] 21.7MiB / 57.5MiB
# Copying blob b3e23ec15d09 done
# Copying blob 85740f1073e7 done
# Copying blob dc76c4afb72d done
# Copying blob a33263ea7965 done
# Copying blob ac81378f5172 done
# Copying blob 8691ca415fb0 done
# Copying blob 92d593a7c63e done
# Copying blob cb883a52b0ac [====================================] 9.3MiB / 9.3MiB
# Copying blob 61efb1f3f8fd done
# Copying blob 6aeea3b7fc68 done
# Copying blob 4f4fb700ef54 done
# Copying blob d299e661dc52 done
# Copying blob 2ab09b027e7f [==============================>---] 26.0MiB / 28.2MiB
# Copying blob 7bd02f0fc242 done
# Copying blob d67242ccbe8c [===============================>--] 29.6MiB / 31.0MiB
# Copying blob c16fb3d4a246 [============>---------------------] 22.7MiB / 57.5MiB
# Copying blob b3e23ec15d09 done
# Copying blob 85740f1073e7 done
# Copying blob dc76c4afb72d done
# Copying blob a33263ea7965 done
# Copying blob ac81378f5172 done
# Copying blob 8691ca415fb0 done
# Copying blob 92d593a7c63e done
# Copying blob cb883a52b0ac done
# Copying blob 61efb1f3f8fd done
# Copying blob 6aeea3b7fc68 done
# Copying blob 4f4fb700ef54 done
# Copying blob d299e661dc52 done
# Copying blob 2ab09b027e7f [================================>-] 27.5MiB / 28.2MiB
# Copying blob 7bd02f0fc242 done
# Copying blob d67242ccbe8c [=================================>] 30.9MiB / 31.0MiB
# Copying blob c16fb3d4a246 [=============>--------------------] 23.7MiB / 57.5MiB
# Copying blob b3e23ec15d09 done
# Copying blob 85740f1073e7 done
# Copying blob dc76c4afb72d done
# Copying blob a33263ea7965 done
# Copying blob ac81378f5172 done
# Copying blob 8691ca415fb0 done
# Copying blob 92d593a7c63e done
# Copying blob cb883a52b0ac done
# Copying blob 61efb1f3f8fd done
# Copying blob 6aeea3b7fc68 done
# Copying blob 4f4fb700ef54 done
# Copying blob d299e661dc52 done
# Copying blob 2ab09b027e7f [==================================] 28.2MiB / 28.2MiB
# Copying blob 7bd02f0fc242 done
# Copying blob d67242ccbe8c [==================================] 31.0MiB / 31.0MiB
# Copying blob c16fb3d4a246 [==============>-------------------] 25.2MiB / 57.5MiB
# Copying blob b3e23ec15d09 done
# Copying blob 85740f1073e7 done
# Copying blob dc76c4afb72d done
# Copying blob a33263ea7965 done
# Copying blob ac81378f5172 done
# Copying blob 8691ca415fb0 done
# Copying blob 92d593a7c63e done
# Copying blob cb883a52b0ac done
# Copying blob 61efb1f3f8fd done
# Copying blob 6aeea3b7fc68 done
# Copying blob 4f4fb700ef54 done
# Copying blob d299e661dc52 done
# Copying blob 2ab09b027e7f done
# Copying blob 7bd02f0fc242 done
# Copying blob d67242ccbe8c done
# Copying blob c16fb3d4a246 [===============>------------------] 26.5MiB / 57.5MiB
# Copying blob b3e23ec15d09 done
# Copying blob 85740f1073e7 done
# Copying blob dc76c4afb72d done
# Copying blob a33263ea7965 done
# Copying blob ac81378f5172 done
# Copying blob 8691ca415fb0 done
# Copying blob 92d593a7c63e done
# Copying blob cb883a52b0ac done
# Copying blob 61efb1f3f8fd done
# Copying blob 6aeea3b7fc68 done
# Copying blob 4f4fb700ef54 done
# Copying blob d299e661dc52 done
# Copying blob 2ab09b027e7f done
# Copying blob 7bd02f0fc242 done
# Copying blob d67242ccbe8c done
# Copying blob c16fb3d4a246 [===============>------------------] 27.6MiB / 57.5MiB
# Copying blob b3e23ec15d09 done
# Copying blob 85740f1073e7 done
# Copying blob dc76c4afb72d done
# Copying blob a33263ea7965 done
# Copying blob ac81378f5172 done
# Copying blob 8691ca415fb0 done
# Copying blob 92d593a7c63e done
# Copying blob cb883a52b0ac done
# Copying blob 61efb1f3f8fd done
# Copying blob 6aeea3b7fc68 done
# Copying blob 4f4fb700ef54 done
# Copying blob d299e661dc52 done
# Copying blob 2ab09b027e7f done
# Copying blob 7bd02f0fc242 done
# Copying blob d67242ccbe8c done
# Copying blob c16fb3d4a246 [================>-----------------] 29.1MiB / 57.5MiB
# Copying blob b3e23ec15d09 done
# Copying blob 85740f1073e7 done
# Copying blob dc76c4afb72d done
# Copying blob a33263ea7965 done
# Copying blob ac81378f5172 done
# Copying blob 8691ca415fb0 done
# Copying blob 92d593a7c63e done
# Copying blob cb883a52b0ac done
# Copying blob 61efb1f3f8fd done
# Copying blob 6aeea3b7fc68 done
# Copying blob 4f4fb700ef54 done
# Copying blob d299e661dc52 done
# Copying blob 2ab09b027e7f done
# Copying blob 7bd02f0fc242 done
# Copying blob d67242ccbe8c done
# Copying blob c16fb3d4a246 [=================>----------------] 30.2MiB / 57.5MiB
# Copying blob b3e23ec15d09 done
# Copying blob 85740f1073e7 done
# Copying blob dc76c4afb72d done
# Copying blob a33263ea7965 done
# Copying blob ac81378f5172 done
# Copying blob 8691ca415fb0 done
# Copying blob 92d593a7c63e done
# Copying blob cb883a52b0ac done
# Copying blob 61efb1f3f8fd done
# Copying blob 6aeea3b7fc68 done
# Copying blob 4f4fb700ef54 done
# Copying blob d299e661dc52 done
# Copying blob 2ab09b027e7f done
# Copying blob 7bd02f0fc242 done
# Copying blob d67242ccbe8c done
# Copying blob c16fb3d4a246 [==================>---------------] 31.4MiB / 57.5MiB
# Copying blob b3e23ec15d09 done
# Copying blob 85740f1073e7 done
# Copying blob dc76c4afb72d done
# Copying blob a33263ea7965 done
# Copying blob ac81378f5172 done
# Copying blob 8691ca415fb0 done
# Copying blob 92d593a7c63e done
# Copying blob cb883a52b0ac done
# Copying blob 61efb1f3f8fd done
# Copying blob 6aeea3b7fc68 done
# Copying blob 4f4fb700ef54 done
# Copying blob d299e661dc52 done
# Copying blob 2ab09b027e7f done
# Copying blob 7bd02f0fc242 done
# Copying blob d67242ccbe8c done
# Copying blob c16fb3d4a246 [==================>---------------] 32.3MiB / 57.5MiB
# Copying blob b3e23ec15d09 done
# Copying blob 85740f1073e7 done
# Copying blob dc76c4afb72d done
# Copying blob a33263ea7965 done
# Copying blob ac81378f5172 done
# Copying blob 8691ca415fb0 done
# Copying blob 92d593a7c63e done
# Copying blob cb883a52b0ac done
# Copying blob 61efb1f3f8fd done
# Copying blob 6aeea3b7fc68 done
# Copying blob 4f4fb700ef54 done
# Copying blob d299e661dc52 done
# Copying blob 2ab09b027e7f done
# Copying blob 7bd02f0fc242 done
# Copying blob d67242ccbe8c done
# Copying blob c16fb3d4a246 [===================>--------------] 33.6MiB / 57.5MiB
# Copying blob b3e23ec15d09 done
# Copying blob 85740f1073e7 done
# Copying blob dc76c4afb72d done
# Copying blob a33263ea7965 done
# Copying blob ac81378f5172 done
# Copying blob 8691ca415fb0 done
# Copying blob 92d593a7c63e done
# Copying blob cb883a52b0ac done
# Copying blob 61efb1f3f8fd done
# Copying blob 6aeea3b7fc68 done
# Copying blob 4f4fb700ef54 done
# Copying blob d299e661dc52 done
# Copying blob 2ab09b027e7f done
# Copying blob 7bd02f0fc242 done
# Copying blob d67242ccbe8c done
# Copying blob c16fb3d4a246 [===================>--------------] 34.6MiB / 57.5MiB
# Copying blob b3e23ec15d09 done
# Copying blob 85740f1073e7 done
# Copying blob dc76c4afb72d done
# Copying blob a33263ea7965 done
# Copying blob ac81378f5172 done
# Copying blob 8691ca415fb0 done
# Copying blob 92d593a7c63e done
# Copying blob cb883a52b0ac done
# Copying blob 61efb1f3f8fd done
# Copying blob 6aeea3b7fc68 done
# Copying blob 4f4fb700ef54 done
# Copying blob d299e661dc52 done
# Copying blob 2ab09b027e7f done
# Copying blob 7bd02f0fc242 done
# Copying blob d67242ccbe8c done
# Copying blob c16fb3d4a246 [====================>-------------] 35.0MiB / 57.5MiB
# Copying blob b3e23ec15d09 done
# Copying blob 85740f1073e7 done
# Copying blob dc76c4afb72d done
# Copying blob a33263ea7965 done
# Copying blob ac81378f5172 done
# Copying blob 8691ca415fb0 done
# Copying blob 92d593a7c63e done
# Copying blob cb883a52b0ac done
# Copying blob 61efb1f3f8fd done
# Copying blob 6aeea3b7fc68 done
# Copying blob 4f4fb700ef54 done
# Copying blob d299e661dc52 done
# Copying blob 2ab09b027e7f done
# Copying blob 7bd02f0fc242 done
# Copying blob d67242ccbe8c done
# Copying blob c16fb3d4a246 [====================>-------------] 35.3MiB / 57.5MiB
# Copying blob b3e23ec15d09 done
# Copying blob 85740f1073e7 done
# Copying blob dc76c4afb72d done
# Copying blob a33263ea7965 done
# Copying blob ac81378f5172 done
# Copying blob 8691ca415fb0 done
# Copying blob 92d593a7c63e done
# Copying blob cb883a52b0ac done
# Copying blob 61efb1f3f8fd done
# Copying blob 6aeea3b7fc68 done
# Copying blob 4f4fb700ef54 done
# Copying blob d299e661dc52 done
# Copying blob 2ab09b027e7f done
# Copying blob 7bd02f0fc242 done
# Copying blob d67242ccbe8c done
# Copying blob c16fb3d4a246 [=====================>------------] 36.4MiB / 57.5MiB
# Copying blob b3e23ec15d09 done
# Copying blob 85740f1073e7 done
# Copying blob dc76c4afb72d done
# Copying blob a33263ea7965 done
# Copying blob ac81378f5172 done
# Copying blob 8691ca415fb0 done
# Copying blob 92d593a7c63e done
# Copying blob cb883a52b0ac done
# Copying blob 61efb1f3f8fd done
# Copying blob 6aeea3b7fc68 done
# Copying blob 4f4fb700ef54 done
# Copying blob d299e661dc52 done
# Copying blob 2ab09b027e7f done
# Copying blob 7bd02f0fc242 done
# Copying blob d67242ccbe8c done
# Copying blob c16fb3d4a246 [=====================>------------] 37.2MiB / 57.5MiB
# Copying blob b3e23ec15d09 done
# Copying blob 85740f1073e7 done
# Copying blob dc76c4afb72d done
# Copying blob a33263ea7965 done
# Copying blob ac81378f5172 done
# Copying blob 8691ca415fb0 done
# Copying blob 92d593a7c63e done
# Copying blob cb883a52b0ac done
# Copying blob 61efb1f3f8fd done
# Copying blob 6aeea3b7fc68 done
# Copying blob 4f4fb700ef54 done
# Copying blob d299e661dc52 done
# Copying blob 2ab09b027e7f done
# Copying blob 7bd02f0fc242 done
# Copying blob d67242ccbe8c done
# Copying blob c16fb3d4a246 [======================>-----------] 38.4MiB / 57.5MiB
# Copying blob b3e23ec15d09 done
# Copying blob 85740f1073e7 done
# Copying blob dc76c4afb72d done
# Copying blob a33263ea7965 done
# Copying blob ac81378f5172 done
# Copying blob 8691ca415fb0 done
# Copying blob 92d593a7c63e done
# Copying blob cb883a52b0ac done
# Copying blob 61efb1f3f8fd done
# Copying blob 6aeea3b7fc68 done
# Copying blob 4f4fb700ef54 done
# Copying blob d299e661dc52 done
# Copying blob 2ab09b027e7f done
# Copying blob 7bd02f0fc242 done
# Copying blob d67242ccbe8c done
# Copying blob c16fb3d4a246 [======================>-----------] 39.2MiB / 57.5MiB
# Copying blob b3e23ec15d09 done
# Copying blob 85740f1073e7 done
# Copying blob dc76c4afb72d done
# Copying blob a33263ea7965 done
# Copying blob ac81378f5172 done
# Copying blob 8691ca415fb0 done
# Copying blob 92d593a7c63e done
# Copying blob cb883a52b0ac done
# Copying blob 61efb1f3f8fd done
# Copying blob 6aeea3b7fc68 done
# Copying blob 4f4fb700ef54 done
# Copying blob d299e661dc52 done
# Copying blob 2ab09b027e7f done
# Copying blob 7bd02f0fc242 done
# Copying blob d67242ccbe8c done
# Copying blob c16fb3d4a246 [=======================>----------] 40.4MiB / 57.5MiB
# Copying blob b3e23ec15d09 done
# Copying blob 85740f1073e7 done
# Copying blob dc76c4afb72d done
# Copying blob a33263ea7965 done
# Copying blob ac81378f5172 done
# Copying blob 8691ca415fb0 done
# Copying blob 92d593a7c63e done
# Copying blob cb883a52b0ac done
# Copying blob 61efb1f3f8fd done
# Copying blob 6aeea3b7fc68 done
# Copying blob 4f4fb700ef54 done
# Copying blob d299e661dc52 done
# Copying blob 2ab09b027e7f done
# Copying blob 7bd02f0fc242 done
# Copying blob d67242ccbe8c done
# Copying blob c16fb3d4a246 [=======================>----------] 40.8MiB / 57.5MiB
# Copying blob b3e23ec15d09 done
# Copying blob 85740f1073e7 done
# Copying blob dc76c4afb72d done
# Copying blob a33263ea7965 done
# Copying blob ac81378f5172 done
# Copying blob 8691ca415fb0 done
# Copying blob 92d593a7c63e done
# Copying blob cb883a52b0ac done
# Copying blob 61efb1f3f8fd done
# Copying blob 6aeea3b7fc68 done
# Copying blob 4f4fb700ef54 done
# Copying blob d299e661dc52 done
# Copying blob 2ab09b027e7f done
# Copying blob 7bd02f0fc242 done
# Copying blob d67242ccbe8c done
# Copying blob c16fb3d4a246 [=======================>----------] 41.3MiB / 57.5MiB
# Copying blob b3e23ec15d09 done
# Copying blob 85740f1073e7 done
# Copying blob dc76c4afb72d done
# Copying blob a33263ea7965 done
# Copying blob ac81378f5172 done
# Copying blob 8691ca415fb0 done
# Copying blob 92d593a7c63e done
# Copying blob cb883a52b0ac done
# Copying blob 61efb1f3f8fd done
# Copying blob 6aeea3b7fc68 done
# Copying blob 4f4fb700ef54 done
# Copying blob d299e661dc52 done
# Copying blob 2ab09b027e7f done
# Copying blob 7bd02f0fc242 done
# Copying blob d67242ccbe8c done
# Copying blob c16fb3d4a246 [========================>---------] 41.9MiB / 57.5MiB
# Copying blob b3e23ec15d09 done
# Copying blob 85740f1073e7 done
# Copying blob dc76c4afb72d done
# Copying blob a33263ea7965 done
# Copying blob ac81378f5172 done
# Copying blob 8691ca415fb0 done
# Copying blob 92d593a7c63e done
# Copying blob cb883a52b0ac done
# Copying blob 61efb1f3f8fd done
# Copying blob 6aeea3b7fc68 done
# Copying blob 4f4fb700ef54 done
# Copying blob d299e661dc52 done
# Copying blob 2ab09b027e7f done
# Copying blob 7bd02f0fc242 done
# Copying blob d67242ccbe8c done
# Copying blob c16fb3d4a246 [========================>---------] 43.0MiB / 57.5MiB
# Copying blob b3e23ec15d09 done
# Copying blob 85740f1073e7 done
# Copying blob dc76c4afb72d done
# Copying blob a33263ea7965 done
# Copying blob ac81378f5172 done
# Copying blob 8691ca415fb0 done
# Copying blob 92d593a7c63e done
# Copying blob cb883a52b0ac done
# Copying blob 61efb1f3f8fd done
# Copying blob 6aeea3b7fc68 done
# Copying blob 4f4fb700ef54 done
# Copying blob d299e661dc52 done
# Copying blob 2ab09b027e7f done
# Copying blob 7bd02f0fc242 done
# Copying blob d67242ccbe8c done
# Copying blob c16fb3d4a246 [=========================>--------] 43.5MiB / 57.5MiB
# Copying blob b3e23ec15d09 done
# Copying blob 85740f1073e7 done
# Copying blob dc76c4afb72d done
# Copying blob a33263ea7965 done
# Copying blob ac81378f5172 done
# Copying blob 8691ca415fb0 done
# Copying blob 92d593a7c63e done
# Copying blob cb883a52b0ac done
# Copying blob 61efb1f3f8fd done
# Copying blob 6aeea3b7fc68 done
# Copying blob 4f4fb700ef54 done
# Copying blob d299e661dc52 done
# Copying blob 2ab09b027e7f done
# Copying blob 7bd02f0fc242 done
# Copying blob d67242ccbe8c done
# Copying blob c16fb3d4a246 [=========================>--------] 43.9MiB / 57.5MiB
# Copying blob b3e23ec15d09 done
# Copying blob 85740f1073e7 done
# Copying blob dc76c4afb72d done
# Copying blob a33263ea7965 done
# Copying blob ac81378f5172 done
# Copying blob 8691ca415fb0 done
# Copying blob 92d593a7c63e done
# Copying blob cb883a52b0ac done
# Copying blob 61efb1f3f8fd done
# Copying blob 6aeea3b7fc68 done
# Copying blob 4f4fb700ef54 done
# Copying blob d299e661dc52 done
# Copying blob 2ab09b027e7f done
# Copying blob 7bd02f0fc242 done
# Copying blob d67242ccbe8c done
# Copying blob c16fb3d4a246 [=========================>--------] 44.1MiB / 57.5MiB
# Copying blob b3e23ec15d09 done
# Copying blob 85740f1073e7 done
# Copying blob dc76c4afb72d done
# Copying blob a33263ea7965 done
# Copying blob ac81378f5172 done
# Copying blob 8691ca415fb0 done
# Copying blob 92d593a7c63e done
# Copying blob cb883a52b0ac done
# Copying blob 61efb1f3f8fd done
# Copying blob 6aeea3b7fc68 done
# Copying blob 4f4fb700ef54 done
# Copying blob d299e661dc52 done
# Copying blob 2ab09b027e7f done
# Copying blob 7bd02f0fc242 done
# Copying blob d67242ccbe8c done
# Copying blob c16fb3d4a246 [=========================>--------] 44.5MiB / 57.5MiB
# Copying blob b3e23ec15d09 done
# Copying blob 85740f1073e7 done
# Copying blob dc76c4afb72d done
# Copying blob a33263ea7965 done
# Copying blob ac81378f5172 done
# Copying blob 8691ca415fb0 done
# Copying blob 92d593a7c63e done
# Copying blob cb883a52b0ac done
# Copying blob 61efb1f3f8fd done
# Copying blob 6aeea3b7fc68 done
# Copying blob 4f4fb700ef54 done
# Copying blob d299e661dc52 done
# Copying blob 2ab09b027e7f done
# Copying blob 7bd02f0fc242 done
# Copying blob d67242ccbe8c done
# Copying blob c16fb3d4a246 [==========================>-------] 45.0MiB / 57.5MiB
# Copying blob b3e23ec15d09 done
# Copying blob 85740f1073e7 done
# Copying blob dc76c4afb72d done
# Copying blob a33263ea7965 done
# Copying blob ac81378f5172 done
# Copying blob 8691ca415fb0 done
# Copying blob 92d593a7c63e done
# Copying blob cb883a52b0ac done
# Copying blob 61efb1f3f8fd done
# Copying blob 6aeea3b7fc68 done
# Copying blob 4f4fb700ef54 done
# Copying blob d299e661dc52 done
# Copying blob 2ab09b027e7f done
# Copying blob 7bd02f0fc242 done
# Copying blob d67242ccbe8c done
# Copying blob c16fb3d4a246 [==========================>-------] 46.1MiB / 57.5MiB
# Copying blob b3e23ec15d09 done
# Copying blob 85740f1073e7 done
# Copying blob dc76c4afb72d done
# Copying blob a33263ea7965 done
# Copying blob ac81378f5172 done
# Copying blob 8691ca415fb0 done
# Copying blob 92d593a7c63e done
# Copying blob cb883a52b0ac done
# Copying blob 61efb1f3f8fd done
# Copying blob 6aeea3b7fc68 done
# Copying blob 4f4fb700ef54 done
# Copying blob d299e661dc52 done
# Copying blob 2ab09b027e7f done
# Copying blob 7bd02f0fc242 done
# Copying blob d67242ccbe8c done
# Copying blob c16fb3d4a246 [===========================>------] 46.8MiB / 57.5MiB
# Copying blob b3e23ec15d09 done
# Copying blob 85740f1073e7 done
# Copying blob dc76c4afb72d done
# Copying blob a33263ea7965 done
# Copying blob ac81378f5172 done
# Copying blob 8691ca415fb0 done
# Copying blob 92d593a7c63e done
# Copying blob cb883a52b0ac done
# Copying blob 61efb1f3f8fd done
# Copying blob 6aeea3b7fc68 done
# Copying blob 4f4fb700ef54 done
# Copying blob d299e661dc52 done
# Copying blob 2ab09b027e7f done
# Copying blob 7bd02f0fc242 done
# Copying blob d67242ccbe8c done
# Copying blob c16fb3d4a246 [===========================>------] 47.5MiB / 57.5MiB
# Copying blob b3e23ec15d09 done
# Copying blob 85740f1073e7 done
# Copying blob dc76c4afb72d done
# Copying blob a33263ea7965 done
# Copying blob ac81378f5172 done
# Copying blob 8691ca415fb0 done
# Copying blob 92d593a7c63e done
# Copying blob cb883a52b0ac done
# Copying blob 61efb1f3f8fd done
# Copying blob 6aeea3b7fc68 done
# Copying blob 4f4fb700ef54 done
# Copying blob d299e661dc52 done
# Copying blob 2ab09b027e7f done
# Copying blob 7bd02f0fc242 done
# Copying blob d67242ccbe8c done
# Copying blob c16fb3d4a246 [===========================>------] 48.0MiB / 57.5MiB
# Copying blob b3e23ec15d09 done
# Copying blob 85740f1073e7 done
# Copying blob dc76c4afb72d done
# Copying blob a33263ea7965 done
# Copying blob ac81378f5172 done
# Copying blob 8691ca415fb0 done
# Copying blob 92d593a7c63e done
# Copying blob cb883a52b0ac done
# Copying blob 61efb1f3f8fd done
# Copying blob 6aeea3b7fc68 done
# Copying blob 4f4fb700ef54 done
# Copying blob d299e661dc52 done
# Copying blob 2ab09b027e7f done
# Copying blob 7bd02f0fc242 done
# Copying blob d67242ccbe8c done
# Copying blob c16fb3d4a246 [============================>-----] 49.1MiB / 57.5MiB
# Copying blob b3e23ec15d09 done
# Copying blob 85740f1073e7 done
# Copying blob dc76c4afb72d done
# Copying blob a33263ea7965 done
# Copying blob ac81378f5172 done
# Copying blob 8691ca415fb0 done
# Copying blob 92d593a7c63e done
# Copying blob cb883a52b0ac done
# Copying blob 61efb1f3f8fd done
# Copying blob 6aeea3b7fc68 done
# Copying blob 4f4fb700ef54 done
# Copying blob d299e661dc52 done
# Copying blob 2ab09b027e7f done
# Copying blob 7bd02f0fc242 done
# Copying blob d67242ccbe8c done
# Copying blob c16fb3d4a246 [=============================>----] 50.1MiB / 57.5MiB
# Copying blob b3e23ec15d09 done
# Copying blob 85740f1073e7 done
# Copying blob dc76c4afb72d done
# Copying blob a33263ea7965 done
# Copying blob ac81378f5172 done
# Copying blob 8691ca415fb0 done
# Copying blob 92d593a7c63e done
# Copying blob cb883a52b0ac done
# Copying blob 61efb1f3f8fd done
# Copying blob 6aeea3b7fc68 done
# Copying blob 4f4fb700ef54 done
# Copying blob d299e661dc52 done
# Copying blob 2ab09b027e7f done
# Copying blob 7bd02f0fc242 done
# Copying blob d67242ccbe8c done
# Copying blob c16fb3d4a246 [==============================>---] 52.0MiB / 57.5MiB
# Copying blob b3e23ec15d09 done
# Copying blob 85740f1073e7 done
# Copying blob dc76c4afb72d done
# Copying blob a33263ea7965 done
# Copying blob ac81378f5172 done
# Copying blob 8691ca415fb0 done
# Copying blob 92d593a7c63e done
# Copying blob cb883a52b0ac done
# Copying blob 61efb1f3f8fd done
# Copying blob 6aeea3b7fc68 done
# Copying blob 4f4fb700ef54 done
# Copying blob d299e661dc52 done
# Copying blob 2ab09b027e7f done
# Copying blob 7bd02f0fc242 done
# Copying blob d67242ccbe8c done
# Copying blob c16fb3d4a246 [==============================>---] 52.9MiB / 57.5MiB
# Copying blob b3e23ec15d09 done
# Copying blob 85740f1073e7 done
# Copying blob dc76c4afb72d done
# Copying blob a33263ea7965 done
# Copying blob ac81378f5172 done
# Copying blob 8691ca415fb0 done
# Copying blob 92d593a7c63e done
# Copying blob cb883a52b0ac done
# Copying blob 61efb1f3f8fd done
# Copying blob 6aeea3b7fc68 done
# Copying blob 4f4fb700ef54 done
# Copying blob d299e661dc52 done
# Copying blob 2ab09b027e7f done
# Copying blob 7bd02f0fc242 done
# Copying blob d67242ccbe8c done
# Copying blob c16fb3d4a246 [===============================>--] 54.9MiB / 57.5MiB
# Copying blob b3e23ec15d09 done
# Copying blob 85740f1073e7 done
# Copying blob dc76c4afb72d done
# Copying blob a33263ea7965 done
# Copying blob ac81378f5172 done
# Copying blob 8691ca415fb0 done
# Copying blob 92d593a7c63e done
# Copying blob cb883a52b0ac done
# Copying blob 61efb1f3f8fd done
# Copying blob 6aeea3b7fc68 done
# Copying blob 4f4fb700ef54 done
# Copying blob d299e661dc52 done
# Copying blob 2ab09b027e7f done
# Copying blob 7bd02f0fc242 done
# Copying blob d67242ccbe8c done
# Copying blob c16fb3d4a246 [================================>-] 56.0MiB / 57.5MiB
# Copying blob b3e23ec15d09 done
# Copying blob 85740f1073e7 done
# Copying blob dc76c4afb72d done
# Copying blob a33263ea7965 done
# Copying blob ac81378f5172 done
# Copying blob 8691ca415fb0 done
# Copying blob 92d593a7c63e done
# Copying blob cb883a52b0ac done
# Copying blob 61efb1f3f8fd done
# Copying blob 6aeea3b7fc68 done
# Copying blob 4f4fb700ef54 done
# Copying blob d299e661dc52 done
# Copying blob 2ab09b027e7f done
# Copying blob 7bd02f0fc242 done
# Copying blob d67242ccbe8c done
# Copying blob c16fb3d4a246 [==================================] 57.5MiB / 57.5MiB
# Copying blob b3e23ec15d09 done
# Copying blob 85740f1073e7 done
# Copying blob dc76c4afb72d done
# Copying blob a33263ea7965 done
# Copying blob ac81378f5172 done
# Copying blob 8691ca415fb0 done
# Copying blob 92d593a7c63e done
# Copying blob cb883a52b0ac done
# Copying blob 61efb1f3f8fd done
# Copying blob 6aeea3b7fc68 done
# Copying blob 4f4fb700ef54 done
# Copying blob d299e661dc52 done
# Copying blob 2ab09b027e7f done
# Copying blob 7bd02f0fc242 done
# Copying blob d67242ccbe8c done
# Copying blob c16fb3d4a246 done
# Copying blob b3e23ec15d09 done
# Copying blob 85740f1073e7 done
# Copying blob dc76c4afb72d done
# Copying blob a33263ea7965 done
# Copying blob ac81378f5172 done
# Copying blob 8691ca415fb0 done
# Copying blob 92d593a7c63e done
# Copying blob cb883a52b0ac done
# Copying blob 61efb1f3f8fd done
# Copying blob 6aeea3b7fc68 done
# Copying blob 4f4fb700ef54 done
# Copying blob d299e661dc52 done
# Copying blob 2ab09b027e7f done
# Copying blob 7bd02f0fc242 done
# Copying blob d67242ccbe8c done
# Copying blob c16fb3d4a246 done
# Copying blob b3e23ec15d09 done
# Copying blob 85740f1073e7 done
# Copying blob dc76c4afb72d done
# Copying blob a33263ea7965 done
# Copying blob ac81378f5172 done
# Copying blob 8691ca415fb0 done
# Copying blob 92d593a7c63e done
# Copying blob cb883a52b0ac done
# Copying blob 61efb1f3f8fd done
# Copying blob 6aeea3b7fc68 done
# Copying blob 4f4fb700ef54 done
# Copying blob d299e661dc52 done
# Copying blob 2ab09b027e7f done
# Copying blob 7bd02f0fc242 done
# Copying blob d67242ccbe8c done
# Copying blob c16fb3d4a246 done
# Copying blob b3e23ec15d09 done
# Copying blob 85740f1073e7 done
# Copying blob dc76c4afb72d done
# Copying blob a33263ea7965 done
# Copying blob ac81378f5172 done
# Copying blob 8691ca415fb0 done
# Copying blob 92d593a7c63e done
# Copying blob cb883a52b0ac done
# Copying blob 61efb1f3f8fd done
# Copying blob 6aeea3b7fc68 done
# Copying blob 4f4fb700ef54 done
# Copying blob d299e661dc52 done
# Copying blob 2ab09b027e7f done
# Copying blob 7bd02f0fc242 done
# Copying blob d67242ccbe8c done
# Copying blob c16fb3d4a246 done
# Copying blob b3e23ec15d09 done
# Copying blob 85740f1073e7 done
# Copying blob dc76c4afb72d done
# Copying blob a33263ea7965 done
# Copying blob ac81378f5172 done
# Copying blob 8691ca415fb0 done
# Copying blob 92d593a7c63e done
# Copying blob cb883a52b0ac done
# Copying blob 61efb1f3f8fd done
# Copying blob 6aeea3b7fc68 done
# Copying blob 4f4fb700ef54 done
# Copying blob d299e661dc52 done
# Copying blob 2ab09b027e7f done
# Copying blob 7bd02f0fc242 done
# Copying blob d67242ccbe8c done
# Copying blob c16fb3d4a246 done
# Copying blob b3e23ec15d09 done
# Copying blob 85740f1073e7 done
# Copying blob dc76c4afb72d done
# Copying blob a33263ea7965 done
# Copying blob ac81378f5172 done
# Copying blob 8691ca415fb0 done
# Copying blob 92d593a7c63e done
# Copying blob cb883a52b0ac done
# Copying blob 61efb1f3f8fd done
# Copying blob 6aeea3b7fc68 done
# Copying blob 4f4fb700ef54 done
# Copying blob d299e661dc52 done
# Copying blob 2ab09b027e7f done
# Copying blob 7bd02f0fc242 done
# Copying blob d67242ccbe8c done
# Copying blob c16fb3d4a246 done
# Copying blob b3e23ec15d09 done
# Copying blob 85740f1073e7 done
# Copying blob dc76c4afb72d done
# Copying blob a33263ea7965 done
# Copying blob ac81378f5172 done
# Copying blob 8691ca415fb0 done
# Copying blob 92d593a7c63e done
# Copying blob cb883a52b0ac done
# Copying blob 61efb1f3f8fd done
# Copying blob 6aeea3b7fc68 done
# Copying blob 4f4fb700ef54 done
# Copying blob d299e661dc52 done
# Copying blob 2ab09b027e7f done
# Copying blob 7bd02f0fc242 done
# Copying blob d67242ccbe8c done
# Copying blob c16fb3d4a246 done
# Copying blob b3e23ec15d09 done
# Copying blob 85740f1073e7 done
# Copying blob dc76c4afb72d done
# Copying blob a33263ea7965 done
# Copying blob ac81378f5172 done
# Copying blob 8691ca415fb0 done
# Copying blob 92d593a7c63e done
# Copying blob cb883a52b0ac done
# Copying blob 61efb1f3f8fd done
# Copying blob 6aeea3b7fc68 done
# Copying blob 4f4fb700ef54 done
# Copying blob d299e661dc52 done
# Copying blob 2ab09b027e7f done
# Copying blob 7bd02f0fc242 done
# Copying blob d67242ccbe8c done
# Copying blob c16fb3d4a246 done
# Copying blob b3e23ec15d09 done
# Copying blob 85740f1073e7 done
# Copying blob dc76c4afb72d done
# Copying blob a33263ea7965 done
# Copying blob ac81378f5172 done
# Copying blob 8691ca415fb0 done
# Copying blob 92d593a7c63e done
# Copying blob cb883a52b0ac done
# Copying blob 61efb1f3f8fd done
# Copying blob 6aeea3b7fc68 done
# Copying blob 4f4fb700ef54 done
# Copying blob d299e661dc52 done
# Copying blob 2ab09b027e7f done
# Copying blob 7bd02f0fc242 done
# Copying blob d67242ccbe8c done
# Copying blob c16fb3d4a246 done
# Copying blob b3e23ec15d09 done
# Copying blob 85740f1073e7 done
# Copying blob dc76c4afb72d done
# Copying blob a33263ea7965 done
# Copying blob ac81378f5172 done
# Copying blob 8691ca415fb0 done
# Copying blob 92d593a7c63e done
# Copying blob cb883a52b0ac done
# Copying blob 61efb1f3f8fd done
# Copying blob 6aeea3b7fc68 done
# Copying blob 4f4fb700ef54 done
# Copying blob d299e661dc52 done
# Copying blob 2ab09b027e7f done
# Copying blob 7bd02f0fc242 done
# Copying blob d67242ccbe8c done
# Copying blob c16fb3d4a246 done
# Copying blob b3e23ec15d09 done
# Copying blob 85740f1073e7 done
# Copying blob dc76c4afb72d done
# Copying blob a33263ea7965 done
# Copying blob ac81378f5172 done
# Copying blob 8691ca415fb0 done
# Copying blob 92d593a7c63e done
# Copying blob cb883a52b0ac done
# Copying blob 61efb1f3f8fd done
# Copying blob 6aeea3b7fc68 done
# Copying blob 4f4fb700ef54 done
# Copying blob d299e661dc52 done
# Copying blob 2ab09b027e7f done
# Copying blob 7bd02f0fc242 done
# Copying blob d67242ccbe8c done
# Copying blob c16fb3d4a246 done
# Copying blob b3e23ec15d09 done
# Copying blob 85740f1073e7 done
# Copying blob dc76c4afb72d done
# Copying blob a33263ea7965 done
# ...
# Preparing to unpack .../35-gnupg-l10n_2.2.27-3ubuntu2.1_all.deb ...
# Unpacking gnupg-l10n (2.2.27-3ubuntu2.1) ...
# Selecting previously unselected package gnupg-utils.
# Preparing to unpack .../36-gnupg-utils_2.2.27-3ubuntu2.1_amd64.deb ...
# Unpacking gnupg-utils (2.2.27-3ubuntu2.1) ...
# Selecting previously unselected package gpg.
# Preparing to unpack .../37-gpg_2.2.27-3ubuntu2.1_amd64.deb ...
# Unpacking gpg (2.2.27-3ubuntu2.1) ...
# Selecting previously unselected package pinentry-curses.
# Preparing to unpack .../38-pinentry-curses_1.1.1-1build2_amd64.deb ...
# Unpacking pinentry-curses (1.1.1-1build2) ...
# Selecting previously unselected package gpg-agent.
# Preparing to unpack .../39-gpg-agent_2.2.27-3ubuntu2.1_amd64.deb ...
# Unpacking gpg-agent (2.2.27-3ubuntu2.1) ...
# Selecting previously unselected package gpg-wks-client.
# Preparing to unpack .../40-gpg-wks-client_2.2.27-3ubuntu2.1_amd64.deb ...
# Unpacking gpg-wks-client (2.2.27-3ubuntu2.1) ...
# Selecting previously unselected package gpg-wks-server.
# Preparing to unpack .../41-gpg-wks-server_2.2.27-3ubuntu2.1_amd64.deb ...
# Unpacking gpg-wks-server (2.2.27-3ubuntu2.1) ...
# Selecting previously unselected package gpgsm.
# Preparing to unpack .../42-gpgsm_2.2.27-3ubuntu2.1_amd64.deb ...
# Unpacking gpgsm (2.2.27-3ubuntu2.1) ...
# Selecting previously unselected package gnupg.
# Preparing to unpack .../43-gnupg_2.2.27-3ubuntu2.1_all.deb ...
# Unpacking gnupg (2.2.27-3ubuntu2.1) ...
# Selecting previously unselected package libstemmer0d:amd64.
# Preparing to unpack .../44-libstemmer0d_2.2.0-1build1_amd64.deb ...
# Unpacking libstemmer0d:amd64 (2.2.0-1build1) ...
# Selecting previously unselected package libxmlb2:amd64.
# Preparing to unpack .../45-libxmlb2_0.3.6-2build1_amd64.deb ...
# Unpacking libxmlb2:amd64 (0.3.6-2build1) ...
# Selecting previously unselected package libappstream4:amd64.
# Preparing to unpack .../46-libappstream4_0.15.2-2_amd64.deb ...
# Unpacking libappstream4:amd64 (0.15.2-2) ...
# Selecting previously unselected package libdw1:amd64.
# Preparing to unpack .../47-libdw1_0.186-1build1_amd64.deb ...
# Unpacking libdw1:amd64 (0.186-1build1) ...
# Selecting previously unselected package libglib2.0-bin.
# Preparing to unpack .../48-libglib2.0-bin_2.72.4-0ubuntu2.2_amd64.deb ...
# Unpacking libglib2.0-bin (2.72.4-0ubuntu2.2) ...
# Selecting previously unselected package libunwind8:amd64.
# Preparing to unpack .../49-libunwind8_1.3.2-2build2.1_amd64.deb ...
# Unpacking libunwind8:amd64 (1.3.2-2build2.1) ...
# Selecting previously unselected package libgstreamer1.0-0:amd64.
# Preparing to unpack .../50-libgstreamer1.0-0_1.20.3-0ubuntu1_amd64.deb ...
# Unpacking libgstreamer1.0-0:amd64 (1.20.3-0ubuntu1) ...
# Selecting previously unselected package libpolkit-gobject-1-0:amd64.
# Preparing to unpack .../51-libpolkit-gobject-1-0_0.105-33_amd64.deb ...
# Unpacking libpolkit-gobject-1-0:amd64 (0.105-33) ...
# Selecting previously unselected package libpolkit-agent-1-0:amd64.
# Preparing to unpack .../52-libpolkit-agent-1-0_0.105-33_amd64.deb ...
# Unpacking libpolkit-agent-1-0:amd64 (0.105-33) ...
# Selecting previously unselected package polkitd.
# Preparing to unpack .../53-polkitd_0.105-33_amd64.deb ...
# Unpacking polkitd (0.105-33) ...
# Selecting previously unselected package pkexec.
# Preparing to unpack .../54-pkexec_0.105-33_amd64.deb ...
# Unpacking pkexec (0.105-33) ...
# Selecting previously unselected package policykit-1.
# Preparing to unpack .../55-policykit-1_0.105-33_amd64.deb ...
# Unpacking policykit-1 (0.105-33) ...
# Selecting previously unselected package packagekit.
# Preparing to unpack .../56-packagekit_1.2.5-2ubuntu2_amd64.deb ...
# Unpacking packagekit (1.2.5-2ubuntu2) ...
# Selecting previously unselected package packagekit-tools.
# Preparing to unpack .../57-packagekit-tools_1.2.5-2ubuntu2_amd64.deb ...
# Unpacking packagekit-tools (1.2.5-2ubuntu2) ...
# Selecting previously unselected package python3-blinker.
# Preparing to unpack .../58-python3-blinker_1.4+dfsg1-0.4_all.deb ...
# Unpacking python3-blinker (1.4+dfsg1-0.4) ...
# Selecting previously unselected package python3-cffi-backend:amd64.
# Preparing to unpack .../59-python3-cffi-backend_1.15.0-1build2_amd64.deb ...
# Unpacking python3-cffi-backend:amd64 (1.15.0-1build2) ...
# Selecting previously unselected package python3-cryptography.
# Preparing to unpack .../60-python3-cryptography_3.4.8-1ubuntu2.2_amd64.deb ...
# Unpacking python3-cryptography (3.4.8-1ubuntu2.2) ...
# Selecting previously unselected package python3-pyparsing.
# Preparing to unpack .../61-python3-pyparsing_2.4.7-1_all.deb ...
# Unpacking python3-pyparsing (2.4.7-1) ...
# Selecting previously unselected package python3-httplib2.
# Preparing to unpack .../62-python3-httplib2_0.20.2-2_all.deb ...
# Unpacking python3-httplib2 (0.20.2-2) ...
# Selecting previously unselected package python3-more-itertools.
# Preparing to unpack .../63-python3-more-itertools_8.10.0-2_all.deb ...
# Unpacking python3-more-itertools (8.10.0-2) ...
# Selecting previously unselected package python3-zipp.
# Preparing to unpack .../64-python3-zipp_1.0.0-3_all.deb ...
# Unpacking python3-zipp (1.0.0-3) ...
# Selecting previously unselected package python3-importlib-metadata.
# Preparing to unpack .../65-python3-importlib-metadata_4.6.4-1_all.deb ...
# Unpacking python3-importlib-metadata (4.6.4-1) ...
# Selecting previously unselected package python3-jeepney.
# Preparing to unpack .../66-python3-jeepney_0.7.1-3_all.deb ...
# Unpacking python3-jeepney (0.7.1-3) ...
# Selecting previously unselected package python3-jwt.
# Preparing to unpack .../67-python3-jwt_2.3.0-1ubuntu0.2_all.deb ...
# Unpacking python3-jwt (2.3.0-1ubuntu0.2) ...
# Selecting previously unselected package python3-secretstorage.
# Preparing to unpack .../68-python3-secretstorage_3.3.1-1_all.deb ...
# Unpacking python3-secretstorage (3.3.1-1) ...
# Selecting previously unselected package python3-keyring.
# Preparing to unpack .../69-python3-keyring_23.5.0-1_all.deb ...
# Unpacking python3-keyring (23.5.0-1) ...
# Selecting previously unselected package python3-lazr.uri.
# Preparing to unpack .../70-python3-lazr.uri_1.0.6-2_all.deb ...
# Unpacking python3-lazr.uri (1.0.6-2) ...
# Selecting previously unselected package python3-wadllib.
# Preparing to unpack .../71-python3-wadllib_1.3.6-1_all.deb ...
# Unpacking python3-wadllib (1.3.6-1) ...
# Selecting previously unselected package python3-distro.
# Preparing to unpack .../72-python3-distro_1.7.0-1_all.deb ...
# Unpacking python3-distro (1.7.0-1) ...
# Selecting previously unselected package python3-oauthlib.
# Preparing to unpack .../73-python3-oauthlib_3.2.0-1ubuntu0.1_all.deb ...
# Unpacking python3-oauthlib (3.2.0-1ubuntu0.1) ...
# Selecting previously unselected package python3-six.
# Preparing to unpack .../74-python3-six_1.16.0-3ubuntu1_all.deb ...
# Unpacking python3-six (1.16.0-3ubuntu1) ...
# Selecting previously unselected package python3-lazr.restfulclient.
# Preparing to unpack .../75-python3-lazr.restfulclient_0.14.4-1_all.deb ...
# Unpacking python3-lazr.restfulclient (0.14.4-1) ...
# Selecting previously unselected package python3-launchpadlib.
# Preparing to unpack .../76-python3-launchpadlib_1.10.16-1_all.deb ...
# Unpacking python3-launchpadlib (1.10.16-1) ...
# Selecting previously unselected package python3-software-properties.
# Preparing to unpack .../77-python3-software-properties_0.99.22.9_all.deb ...
# Unpacking python3-software-properties (0.99.22.9) ...
# Selecting previously unselected package software-properties-common.
# Preparing to unpack .../78-software-properties-common_0.99.22.9_all.deb ...
# Unpacking software-properties-common (0.99.22.9) ...
# Selecting previously unselected package unattended-upgrades.
# Preparing to unpack .../79-unattended-upgrades_2.8ubuntu1_all.deb ...
# Unpacking unattended-upgrades (2.8ubuntu1) ...
# Setting up libksba8:amd64 (1.6.0-2ubuntu0.2) ...
# Setting up python3-more-itertools (8.10.0-2) ...
# Setting up systemd-sysv (249.11-0ubuntu3.12) ...
# Setting up xdg-user-dirs (0.17-2ubuntu4) ...
# Setting up python3-jwt (2.3.0-1ubuntu0.2) ...
# Setting up libyaml-0-2:amd64 (0.2.2-1build2) ...
# Setting up libglib2.0-0:amd64 (2.72.4-0ubuntu2.2) ...
# No schema files found: doing nothing.
# Setting up distro-info-data (0.52ubuntu0.6) ...
# Setting up libxmlb2:amd64 (0.3.6-2build1) ...
# Setting up libpackagekit-glib2-18:amd64 (1.2.5-2ubuntu2) ...
# Setting up libnss-systemd:amd64 (249.11-0ubuntu3.12) ...
# First installation detected...
# Checking NSS setup...
# Setting up libnpth0:amd64 (1.6-3build2) ...
# Setting up python3-lazr.uri (1.0.6-2) ...
# Setting up libassuan0:amd64 (2.5.5-1build1) ...
# Setting up python3-zipp (1.0.0-3) ...
# Setting up libunwind8:amd64 (1.3.2-2build2.1) ...
# Setting up libcap2-bin (1:2.44-1ubuntu0.22.04.1) ...
# Setting up python3-six (1.16.0-3ubuntu1) ...
# Setting up libglib2.0-data (2.72.4-0ubuntu2.2) ...
# Setting up python3-pyparsing (2.4.7-1) ...
# Setting up gnupg-l10n (2.2.27-3ubuntu2.1) ...
# Setting up python3-wadllib (1.3.6-1) ...
# Setting up libdbus-1-3:amd64 (1.12.20-2ubuntu4.1) ...
# Setting up dbus (1.12.20-2ubuntu4.1) ...
# Setting up xz-utils (5.2.5-2ubuntu1) ...
# update-alternatives: using /usr/bin/xz to provide /usr/bin/lzma (lzma) in auto mode
# update-alternatives: warning: skip creation of /usr/share/man/man1/lzma.1.gz because associated file /usr/share/man/man1/xz.1.gz (of link group lzma) doesn't exist
# update-alternatives: warning: skip creation of /usr/share/man/man1/unlzma.1.gz because associated file /usr/share/man/man1/unxz.1.gz (of link group lzma) doesn't exist
# update-alternatives: warning: skip creation of /usr/share/man/man1/lzcat.1.gz because associated file /usr/share/man/man1/xzcat.1.gz (of link group lzma) doesn't exist
# update-alternatives: warning: skip creation of /usr/share/man/man1/lzmore.1.gz because associated file /usr/share/man/man1/xzmore.1.gz (of link group lzma) doesn't exist
# update-alternatives: warning: skip creation of /usr/share/man/man1/lzless.1.gz because associated file /usr/share/man/man1/xzless.1.gz (of link group lzma) doesn't exist
# update-alternatives: warning: skip creation of /usr/share/man/man1/lzdiff.1.gz because associated file /usr/share/man/man1/xzdiff.1.gz (of link group lzma) doesn't exist
# update-alternatives: warning: skip creation of /usr/share/man/man1/lzcmp.1.gz because associated file /usr/share/man/man1/xzcmp.1.gz (of link group lzma) doesn't exist
# update-alternatives: warning: skip creation of /usr/share/man/man1/lzgrep.1.gz because associated file /usr/share/man/man1/xzgrep.1.gz (of link group lzma) doesn't exist
# update-alternatives: warning: skip creation of /usr/share/man/man1/lzegrep.1.gz because associated file /usr/share/man/man1/xzegrep.1.gz (of link group lzma) doesn't exist
# update-alternatives: warning: skip creation of /usr/share/man/man1/lzfgrep.1.gz because associated file /usr/share/man/man1/xzfgrep.1.gz (of link group lzma) doesn't exist
# Setting up shared-mime-info (2.1-2) ...
# Setting up systemd-timesyncd (249.11-0ubuntu3.12) ...
# Created symlink /etc/systemd/system/dbus-org.freedesktop.timesync1.service → /lib/systemd/system/systemd-timesyncd.service.
# Created symlink /etc/systemd/system/sysinit.target.wants/systemd-timesyncd.service → /lib/systemd/system/systemd-timesyncd.service.
# Setting up ucf (3.0043) ...
# debconf: unable to initialize frontend: Dialog
# debconf: (TERM is not set, so the dialog frontend is not usable.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (Can't locate Term/ReadLine.pm in @INC (you may need to install the Term::ReadLine module) (@INC contains: /etc/perl /usr/local/lib/x86_64-linux-gnu/perl/5.34.0 /usr/local/share/perl/5.34.0 /usr/lib/x86_64-linux-gnu/perl5/5.34 /usr/share/perl5 /usr/lib/x86_64-linux-gnu/perl-base /usr/lib/x86_64-linux-gnu/perl/5.34 /usr/share/perl/5.34 /usr/local/lib/site_perl) at /usr/share/perl5/Debconf/FrontEnd/Readline.pm line 7.)
# debconf: falling back to frontend: Teletype
# Setting up python3-jeepney (0.7.1-3) ...
# Setting up python-apt-common (2.4.0ubuntu3) ...
# Setting up dmsetup (2:1.02.175-2.1ubuntu4) ...
# Setting up gpgconf (2.2.27-3ubuntu2.1) ...
# Setting up python3-httplib2 (0.20.2-2) ...
# Setting up libpam-systemd:amd64 (249.11-0ubuntu3.12) ...
# debconf: unable to initialize frontend: Dialog
# debconf: (TERM is not set, so the dialog frontend is not usable.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (Can't locate Term/ReadLine.pm in @INC (you may need to install the Term::ReadLine module) (@INC contains: /etc/perl /usr/local/lib/x86_64-linux-gnu/perl/5.34.0 /usr/local/share/perl/5.34.0 /usr/lib/x86_64-linux-gnu/perl5/5.34 /usr/share/perl5 /usr/lib/x86_64-linux-gnu/perl-base /usr/lib/x86_64-linux-gnu/perl/5.34 /usr/share/perl/5.34 /usr/local/lib/site_perl) at /usr/share/perl5/Debconf/FrontEnd/Readline.pm line 7.)
# debconf: falling back to frontend: Teletype
# Setting up libgirepository-1.0-1:amd64 (1.72.0-1) ...
# Setting up libstemmer0d:amd64 (2.2.0-1build1) ...
# Setting up lsb-release (11.1.0ubuntu4) ...
# Setting up libelf1:amd64 (0.186-1build1) ...
# Setting up libpam-cap:amd64 (1:2.44-1ubuntu0.22.04.1) ...
# debconf: unable to initialize frontend: Dialog
# debconf: (TERM is not set, so the dialog frontend is not usable.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (Can't locate Term/ReadLine.pm in @INC (you may need to install the Term::ReadLine module) (@INC contains: /etc/perl /usr/local/lib/x86_64-linux-gnu/perl/5.34.0 /usr/local/share/perl/5.34.0 /usr/lib/x86_64-linux-gnu/perl5/5.34 /usr/share/perl5 /usr/lib/x86_64-linux-gnu/perl-base /usr/lib/x86_64-linux-gnu/perl/5.34 /usr/share/perl/5.34 /usr/local/lib/site_perl) at /usr/share/perl5/Debconf/FrontEnd/Readline.pm line 7.)
# debconf: falling back to frontend: Teletype
# Setting up python3-distro-info (1.1ubuntu0.2) ...
# Setting up iso-codes (4.9.0-1) ...
# Setting up gpg (2.2.27-3ubuntu2.1) ...
# Setting up libpolkit-gobject-1-0:amd64 (0.105-33) ...
# Setting up python3-cffi-backend:amd64 (1.15.0-1build2) ...
# Setting up gnupg-utils (2.2.27-3ubuntu2.1) ...
# Setting up python3-blinker (1.4+dfsg1-0.4) ...
# Setting up pinentry-curses (1.1.1-1build2) ...
# Setting up libdw1:amd64 (0.186-1build1) ...
# Setting up python3-dbus (1.2.18-3build1) ...
# Setting up gpg-agent (2.2.27-3ubuntu2.1) ...
# Created symlink /etc/systemd/user/sockets.target.wants/gpg-agent-browser.socket → /usr/lib/systemd/user/gpg-agent-browser.socket.
# Created symlink /etc/systemd/user/sockets.target.wants/gpg-agent-extra.socket → /usr/lib/systemd/user/gpg-agent-extra.socket.
# Created symlink /etc/systemd/user/sockets.target.wants/gpg-agent-ssh.socket → /usr/lib/systemd/user/gpg-agent-ssh.socket.
# Created symlink /etc/systemd/user/sockets.target.wants/gpg-agent.socket → /usr/lib/systemd/user/gpg-agent.socket.
# Setting up python3-importlib-metadata (4.6.4-1) ...
# Setting up python3-distro (1.7.0-1) ...
# Setting up python3-apt (2.4.0ubuntu3) ...
# Setting up gpgsm (2.2.27-3ubuntu2.1) ...
# Setting up libglib2.0-bin (2.72.4-0ubuntu2.2) ...
# Setting up libappstream4:amd64 (0.15.2-2) ...
# Setting up dirmngr (2.2.27-3ubuntu2.1) ...
# Created symlink /etc/systemd/user/sockets.target.wants/dirmngr.socket → /usr/lib/systemd/user/dirmngr.socket.
# Setting up unattended-upgrades (2.8ubuntu1) ...
# debconf: unable to initialize frontend: Dialog
# debconf: (TERM is not set, so the dialog frontend is not usable.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (Can't locate Term/ReadLine.pm in @INC (you may need to install the Term::ReadLine module) (@INC contains: /etc/perl /usr/local/lib/x86_64-linux-gnu/perl/5.34.0 /usr/local/share/perl/5.34.0 /usr/lib/x86_64-linux-gnu/perl5/5.34 /usr/share/perl5 /usr/lib/x86_64-linux-gnu/perl-base /usr/lib/x86_64-linux-gnu/perl/5.34 /usr/share/perl/5.34 /usr/local/lib/site_perl) at /usr/share/perl5/Debconf/FrontEnd/Readline.pm line 7.)
# debconf: falling back to frontend: Teletype
#
# Creating config file /etc/apt/apt.conf.d/20auto-upgrades with new version
#
# Creating config file /etc/apt/apt.conf.d/50unattended-upgrades with new version

# %% [markdown]
# List the built image:

# %%
podman images
# Out:
# REPOSITORY          TAG                 IMAGE ID      CREATED        SIZE
# localhost/rio       latest              18567d3a0b58  3 minutes ago  840 MB
# ghcr.io/osgeo/gdal  ubuntu-small-3.6.4  cba915a8d8ea  11 months ago  353 MB

# %% [markdown]
# Test the container:

# %%
podman run --rm -it localhost/rio:latest rio --help
# Out:
# Usage: rio [OPTIONS] COMMAND [ARGS]...
#
#   Rasterio command line interface.
#
# Options:
#   -v, --verbose           Increase verbosity.
#   -q, --quiet             Decrease verbosity.
#   --aws-profile TEXT      Select a profile from the AWS credentials file
#   --aws-no-sign-requests  Make requests anonymously
#   --aws-requester-pays    Requester pays data transfer costs
#   --version               Show the version and exit.
#   --gdal-version
#   --show-versions         Show dependency versions
#   --help                  Show this message and exit.
#
# Commands:
#   blocks     Write dataset blocks as GeoJSON features.
#   bounds     Write bounding boxes to stdout as GeoJSON.
#   calc       Raster data calculator.
#   clip       Clip a raster to given bounds.
#   convert    Copy and convert raster dataset.
#   edit-info  Edit dataset metadata.
#   env        Print information about the Rasterio environment.
#   gcps       Print ground control points as GeoJSON.
#   info       Print information about a data file.
#   insp       Open a data file and start an interpreter.
#   mask       Mask in raster using features.
#   merge      Merge a stack of raster datasets.
#   overview   Construct overviews in an existing dataset.
#   rasterize  Rasterize features.
#   rm         Delete a dataset.
#   sample     Sample a dataset.
#   shapes     Write shapes extracted from bands or masks.
#   stack      Stack a number of bands into a multiband dataset.
#   transform  Transform coordinates.
#   warp       Warp a raster dataset.
